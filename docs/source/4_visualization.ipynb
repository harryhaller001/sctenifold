# %% [markdown]
# # 4. Network Visualization

# %%
from pathlib import Path
import sys

sys.path.append(str(Path("../../").resolve()))
import scTenifold as st
from scTenifold.data import get_test_df

# %%
from scTenifold.plotting import plot_network_heatmap, plot_qqplot, plot_network_graph

# %% [markdown]
# ### Load existing results

# %%
net = st.scTenifoldNet.load("./path")

td = net.tensor_dict["X"]

# %%
plot_network_heatmap(td)

# %%
plot_qqplot(net.d_regulation["d_regulation"])
